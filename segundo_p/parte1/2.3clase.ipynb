# %%
import cv2 as cv

# %%
imagen = cv.imread("/Users/danielavalencia/Desktop/Procesamiento de Imágenes/OpenCV-images/squirrel_cls.jpg",0)

# %%
import matplotlib.pyplot as plt
plt.imshow(imagen)

# %%
imagen=cv.cvtColor(imagen,cv.COLOR_GRAY2RGB)
plt.imshow(imagen)

# %%
img_res= imagen.copy()

# %% [markdown]
# UMBRALIZACION

# %%
filas,columnas=imagen.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/danielavalencia/Desktop/Procesamiento de Imágenes/2.segundo parcial/2.3clase.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/Users/danielavalencia/Desktop/Procesamiento%20de%20Im%C3%A1genes/2.segundo%20parcial/2.3clase.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> filas,columnas=imagen.shape
#
# ValueError: too many values to unpack (expected 2)

# %%
for f in range (filas):
    for c in columns:
        if imagen[f,c]>=128:
                img_res[f,c]= 255
        else:
                img_res[f,c]=0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/danielavalencia/Desktop/Procesamiento de Imágenes/2.segundo parcial/2.3clase.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/Users/danielavalencia/Desktop/Procesamiento%20de%20Im%C3%A1genes/2.segundo%20parcial/2.3clase.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> for f in range (filas):
#       <a href='vscode-notebook-cell:/Users/danielavalencia/Desktop/Procesamiento%20de%20Im%C3%A1genes/2.segundo%20parcial/2.3clase.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a>     for c in columns:
#       <a href='vscode-notebook-cell:/Users/danielavalencia/Desktop/Procesamiento%20de%20Im%C3%A1genes/2.segundo%20parcial/2.3clase.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a>         if imagen[f,c]>=128:
#
# TypeError: 'tuple' object cannot be interpreted as an integer

# %%
plt.imshow(img_res, cmap="gray")

# %% [markdown]
# OTRA MANERA DE LA UMBRALIZACIÓN

# %%
img_bin=cv.threshold(imagen,128,255, cv.THRESH_BINARY_INV)[1]

# %%
plt.imshow(img_bin,cmap="gray")

# %%
from glob import glob

# %%
lista_archivos= glob("/Users/danielavalencia/Desktop/Procesamiento de Imágenes/OpenCV-images/*")

# %%
lista_archivos
# Out:
# ['/Users/danielavalencia/Desktop/Procesamiento de Imágenes/OpenCV-images/left09.jpg',
#  '/Users/danielavalencia/Desktop/Procesamiento de Imágenes/OpenCV-images/alphabet_36.txt',
#  '/Users/danielavalencia/Desktop/Procesamiento de Imágenes/OpenCV-images/licenseplate_motion.jpg',
#  '/Users/danielavalencia/Desktop/Procesamiento de Imágenes/OpenCV-images/fruits.jpg',
#  '/Users/danielavalencia/Desktop/Procesamiento de Imágenes/OpenCV-images/gradient.png',
#  '/Users/danielavalencia/Desktop/Procesamiento de Imágenes/OpenCV-images/left08.jpg',
#  '/Users/danielavalencia/Desktop/Procesamiento de Imágenes/OpenCV-images/sudoku.png',
#  '/Users/danielavalencia/Desktop/Procesamiento de Imágenes/OpenCV-images/lena.jpg',
#  '/Users/danielavalencia/Desktop/Procesamiento de Imágenes/OpenCV-images/imageTextR.png',
#  '/Users/danielavalencia/Desktop/Procesamiento de Imágenes/OpenCV-images/smarties.png',
# ...
