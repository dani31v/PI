# %%
import cv2 as cv
import matplotlib.pyplot as plt
imagen = cv.imread("/Users/danielavalencia/Desktop/Procesamiento de Imágenes/OpenCV-images/fruits.jpg",0)
plt.imshow(imagen, cmap = "gray")

# %%
histograma = cv.calcHist([imagen],[0],None,[256],(0,255))

# %%
type(histograma)
# Out:
# numpy.ndarray

# %%
histograma.shape
# Out:
# (256, 1)

# %%
plt.imshow(histograma)

# %%
plt.plot(histograma)
